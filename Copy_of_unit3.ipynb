# %% [markdown]
# <a href="https://colab.research.google.com/github/GhazaleZe/RL_Learning_Path/blob/main/Copy_of_unit3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unit 3: Deep Q-Learning with Atari Games 👾 using RL Baselines3 Zoo
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/thumbnail.jpg" alt="Unit 3 Thumbnail">
#
# In this notebook, **you'll train a Deep Q-Learning agent** playing Space Invaders using [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo), a training framework based on [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) that provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# We're using the [RL-Baselines-3 Zoo integration, a vanilla version of Deep Q-Learning](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) with no extensions such as Double-DQN, Dueling-DQN, and Prioritized Experience Replay.
#
# ⬇️ Here is an example of what **you will achieve** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### 🎮 Environments:
#
# - [SpacesInvadersNoFrameskip-v4](https://gymnasium.farama.org/environments/atari/space_invaders/)
#
# You can see the difference between Space Invaders versions here 👉 https://gymnasium.farama.org/environments/atari/space_invaders/#variants
#
# ### 📚 RL-Library:
#
# - [RL-Baselines3-Zoo](https://github.com/DLR-RM/rl-baselines3-zoo)

# %% [markdown]
# ## Objectives of this notebook 🏆
# At the end of the notebook, you will:
# - Be able to understand deeper **how RL Baselines3 Zoo works**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 **[Study Deep Q-Learning by reading Unit 3](https://huggingface.co/deep-rl-course/unit3/introduction)**  🤗

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# # Let's train a Deep Q-Learning agent playing Atari' Space Invaders 👾 and upload it to the Hub.
#
# We strongly recommend students **to use Google Colab for the hands-on exercises instead of running them on their personal computers**.
#
# By using Google Colab, **you can focus on learning and experimenting without worrying about the technical aspects of setting up your environments**.
#
# To validate this hands-on for the certification process, you need to push your trained model to the Hub and **get a result of >= 200**.
#
# To find your result, go to the leaderboard and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## An advice 💡
# It's better to run this colab in a copy on your Google Drive, so that **if it timeouts** you still have the saved notebook on your Google Drive and do not need to fill everything from scratch.
#
# To do that you can either do `Ctrl + S` or `File > Save a copy in Google Drive.`
#
# Also, we're going to **train it for 90 minutes with 1M timesteps**. By typing `!nvidia-smi` will tell you what GPU you're using.
#
# And if you want to train more such 10 million steps, this will take about 9 hours, potentially resulting in Colab timing out. In that case, I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# # Install RL-Baselines3 Zoo and its dependencies 📚
#
# If you see `ERROR: pip's dependency resolver does not currently take into account all the packages that are installed.` **this is normal and it's not a critical error** there's a conflict of version. But the packages we need are installed.

# %%
# For now we install this update of RL-Baselines3 Zoo
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo@update/hf
# Out:
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo@update/hf
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo (to revision update/hf) to /tmp/pip-req-build-34bcgyf5
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-34bcgyf5
#   Running command git checkout -b update/hf --track origin/update/hf
#   Switched to a new branch 'update/hf'
#   Branch 'update/hf' set up to track remote branch 'update/hf' from 'origin'.
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit 7dcbff7e74e7a12c052452181ff353a4dbed313a
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting sb3-contrib>=2.0.0a9 (from rl-zoo3==2.0.0a9)
#   Downloading sb3_contrib-2.1.0-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 2.6 MB/s eta 0:00:00
# Collecting gym==0.26.2 (from rl-zoo3==2.0.0a9)
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 kB 39.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting huggingface-sb3>=2.2.1 (from rl-zoo3==2.0.0a9)
#   Downloading huggingface_sb3-2.3-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from rl-zoo3==2.0.0a9) (4.66.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from rl-zoo3==2.0.0a9) (13.5.2)
# Collecting optuna (from rl-zoo3==2.0.0a9)
#   Downloading optuna-3.3.0-py3-none-any.whl (404 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.2/404.2 kB 46.9 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from rl-zoo3==2.0.0a9) (6.0.1)
# Collecting pytablewriter~=0.64 (from rl-zoo3==2.0.0a9)
#   Downloading pytablewriter-0.64.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym==0.26.2->rl-zoo3==2.0.0a9) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym==0.26.2->rl-zoo3==2.0.0a9) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym==0.26.2->rl-zoo3==2.0.0a9) (0.0.8)
# Collecting huggingface-hub~=0.8 (from huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 38.3 MB/s eta 0:00:00
# Requirement already satisfied: wasabi in /usr/local/lib/python3.10/dist-packages (from huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (1.1.2)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter~=0.64->rl-zoo3==2.0.0a9) (67.7.2)
# Collecting DataProperty<2,>=0.55.0 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Downloading DataProperty-1.0.1-py3-none-any.whl (27 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Downloading mbstrdecoder-1.1.3-py3-none-any.whl (7.8 kB)
# Collecting pathvalidate<3,>=2.3.0 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Downloading pathvalidate-2.5.2-py3-none-any.whl (20 kB)
# Collecting tabledata<2,>=1.3.0 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Downloading tabledata-1.3.1-py3-none-any.whl (11 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Downloading tcolorpy-0.1.3-py3-none-any.whl (7.9 kB)
# Collecting typepy[datetime]<2,>=1.2.0 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Downloading typepy-1.3.1-py3-none-any.whl (31 kB)
# Collecting stable-baselines3>=2.1.0 (from sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9)
#   Downloading stable_baselines3-2.1.0-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 20.5 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna->rl-zoo3==2.0.0a9)
#   Downloading alembic-1.11.3-py3-none-any.whl (225 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.4/225.4 kB 30.5 MB/s eta 0:00:00
# Collecting cmaes>=0.10.0 (from optuna->rl-zoo3==2.0.0a9)
#   Downloading cmaes-0.10.0-py3-none-any.whl (29 kB)
# Collecting colorlog (from optuna->rl-zoo3==2.0.0a9)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna->rl-zoo3==2.0.0a9) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna->rl-zoo3==2.0.0a9) (2.0.20)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->rl-zoo3==2.0.0a9) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->rl-zoo3==2.0.0a9) (2.16.1)
# Collecting Mako (from alembic>=1.5.0->optuna->rl-zoo3==2.0.0a9)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna->rl-zoo3==2.0.0a9) (4.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2.31.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->rl-zoo3==2.0.0a9) (0.1.2)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.10/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (5.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna->rl-zoo3==2.0.0a9) (2.0.2)
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9)
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 40.7 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (2.0.1+cu118)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.7.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (2023.3)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (16.0.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna->rl-zoo3==2.0.0a9) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.3.0)
# Building wheels for collected packages: rl-zoo3, gym
#   Building wheel for rl-zoo3 (pyproject.toml) ... done
#   Created wheel for rl-zoo3: filename=rl_zoo3-2.0.0a9-py3-none-any.whl size=76401 sha256=68c2d8ec4650f6381669ebde14852adba9477ff43fbd77d6f5b9d5b42e26eb0d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tufd7197/wheels/fc/36/d5/2ef574649d85327de098075c8523da50be2612f3e5807261f7
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827621 sha256=1b0240800d57679bb06a5a63cd6fa3a08da517f000baf89bc3eb61b31d014be9
#   Stored in directory: /root/.cache/pip/wheels/b9/22/6d/3e7b32d98451b4cd9d12417052affbeeeea012955d437da1da
# Successfully built rl-zoo3 gym
# Installing collected packages: farama-notifications, tcolorpy, pathvalidate, mbstrdecoder, Mako, gymnasium, gym, colorlog, cmaes, typepy, huggingface-hub, alembic, optuna, huggingface-sb3, DataProperty, tabledata, pytablewriter, stable-baselines3, sb3-contrib, rl-zoo3
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.0.6 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# Successfully installed DataProperty-1.0.1 Mako-1.2.4 alembic-1.11.3 cmaes-0.10.0 colorlog-6.7.0 farama-notifications-0.0.4 gym-0.26.2 gymnasium-0.29.1 huggingface-hub-0.16.4 huggingface-sb3-2.3 mbstrdecoder-1.1.3 optuna-3.3.0 pathvalidate-2.5.2 pytablewriter-0.64.2 rl-zoo3-2.0.0a9 sb3-contrib-2.1.0 stable-baselines3-2.1.0 tabledata-1.3.1 tcolorpy-0.1.3 typepy-1.3.1

# %% [markdown]
# IF AND ONLY IF THE VERSION ABOVE DOES NOT EXIST ANYMORE. UNCOMMENT AND INSTALL THE ONE BELOW

# %%
# !pip install rl_zoo3==2.0.0a9
# Out:
# Requirement already satisfied: rl_zoo3==2.0.0a9 in /usr/local/lib/python3.10/dist-packages (2.0.0a9)
# Requirement already satisfied: sb3-contrib>=2.0.0a9 in /usr/local/lib/python3.10/dist-packages (from rl_zoo3==2.0.0a9) (2.1.0)
# Requirement already satisfied: gym==0.26.2 in /usr/local/lib/python3.10/dist-packages (from rl_zoo3==2.0.0a9) (0.26.2)
# Requirement already satisfied: huggingface-sb3>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from rl_zoo3==2.0.0a9) (2.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from rl_zoo3==2.0.0a9) (4.66.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from rl_zoo3==2.0.0a9) (13.5.2)
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (from rl_zoo3==2.0.0a9) (3.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from rl_zoo3==2.0.0a9) (6.0.1)
# Requirement already satisfied: pytablewriter~=0.64 in /usr/local/lib/python3.10/dist-packages (from rl_zoo3==2.0.0a9) (0.64.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym==0.26.2->rl_zoo3==2.0.0a9) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym==0.26.2->rl_zoo3==2.0.0a9) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym==0.26.2->rl_zoo3==2.0.0a9) (0.0.8)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.10/dist-packages (from huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (0.16.4)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.10/dist-packages (from huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (1.1.2)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter~=0.64->rl_zoo3==2.0.0a9) (67.7.2)
# Requirement already satisfied: DataProperty<2,>=0.55.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter~=0.64->rl_zoo3==2.0.0a9) (1.0.1)
# Requirement already satisfied: mbstrdecoder<2,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter~=0.64->rl_zoo3==2.0.0a9) (1.1.3)
# Requirement already satisfied: pathvalidate<3,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter~=0.64->rl_zoo3==2.0.0a9) (2.5.2)
# Requirement already satisfied: tabledata<2,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter~=0.64->rl_zoo3==2.0.0a9) (1.3.1)
# Requirement already satisfied: tcolorpy<1,>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from pytablewriter~=0.64->rl_zoo3==2.0.0a9) (0.1.3)
# Requirement already satisfied: typepy[datetime]<2,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter~=0.64->rl_zoo3==2.0.0a9) (1.3.1)
# Requirement already satisfied: stable-baselines3>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (2.1.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna->rl_zoo3==2.0.0a9) (1.11.3)
# Requirement already satisfied: cmaes>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from optuna->rl_zoo3==2.0.0a9) (0.10.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna->rl_zoo3==2.0.0a9) (6.7.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna->rl_zoo3==2.0.0a9) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna->rl_zoo3==2.0.0a9) (2.0.20)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->rl_zoo3==2.0.0a9) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->rl_zoo3==2.0.0a9) (2.16.1)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna->rl_zoo3==2.0.0a9) (1.2.4)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna->rl_zoo3==2.0.0a9) (4.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (2.31.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->rl_zoo3==2.0.0a9) (0.1.2)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.10/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter~=0.64->rl_zoo3==2.0.0a9) (5.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna->rl_zoo3==2.0.0a9) (2.0.2)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (0.29.1)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (2.0.1+cu118)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (3.7.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl_zoo3==2.0.0a9) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl_zoo3==2.0.0a9) (2023.3)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (0.0.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl_zoo3==2.0.0a9) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (16.0.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna->rl_zoo3==2.0.0a9) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (1.3.0)

# %%
# !apt-get install swig cmake ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.1).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 16 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 2s (456 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 120831 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %% [markdown]
# To be able to use Atari games in Gymnasium we need to install atari package. And accept-rom-license to download the rom files (games files).

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]
# Out:
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (4.7.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (0.0.4)
# Collecting shimmy[atari]<1.0,>=0.1.0 (from gymnasium[atari])
#   Downloading Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Collecting ale-py~=0.8.1 (from shimmy[atari]<1.0,>=0.1.0->gymnasium[atari])
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 30.0 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]<1.0,>=0.1.0->gymnasium[atari]) (6.0.1)
# Installing collected packages: ale-py, shimmy
# Successfully installed ale-py-0.8.1 shimmy-0.2.1
# Requirement already satisfied: gymnasium[accept-rom-license] in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (4.7.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (0.0.4)
# Collecting autorom[accept-rom-license]~=0.4.2 (from gymnasium[accept-rom-license])
#   Downloading AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (4.66.1)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 9.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (2023.7.22)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446660 sha256=3cf2fcd83a8681779aa9fa1453c428444e563423b8d706257de4a51267e5f4db
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: AutoROM.accept-rom-license, autorom
# Successfully installed AutoROM.accept-rom-license-0.6.1 autorom-0.4.2

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# %%capture
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ## Train our Deep Q-Learning Agent to Play Space Invaders 👾
#
# To train an agent with RL-Baselines3-Zoo, we just need to do two things:
#
# 1. Create a hyperparameter config file that will contain our training hyperparameters called `dqn.yml`.
#
# This is a template example:
#
# ```
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e7
#   buffer_size: 100000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   learning_starts: 100000
#   target_update_interval: 1000
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   # If True, you need to deactivate handle_timeout_termination
#   # in the replay_buffer_kwargs
#   optimize_memory_usage: False
# ```

# %% [markdown]
# Here we see that:
# - We use the `Atari Wrapper` that preprocess the input (Frame reduction ,grayscale, stack 4 frames)
# - We use `CnnPolicy`, since we use Convolutional layers to process the frames
# - We train it for 10 million `n_timesteps`
# - Memory (Experience Replay) size is 100000, aka the amount of experience steps you saved to train again your agent with.
#
# 💡 My advice is to **reduce the training timesteps to 1M,** which will take about 90 minutes on a P100. `!nvidia-smi` will tell you what GPU you're using. At 10 million steps, this will take about 9 hours, which could likely result in Colab timing out. I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# In terms of hyperparameters optimization, my advice is to focus on these 3 hyperparameters:
# - `learning_rate`
# - `buffer_size (Experience Memory size)`
# - `batch_size`
#
# As a good practice, you need to **check the documentation to understand what each hyperparameters does**: https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html#parameters

# %% [markdown]
# 2. We start the training and save the models on `logs` folder 📁
#
# - Define the algorithm after `--algo`, where we save the model after `-f` and where the hyperparameter config is after `-c`.

# %%
# !python -m rl_zoo3.train --algo _____________________ --env SpaceInvadersNoFrameskip-v4  -f ______  -c _________

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml
# Out:
# Streaming output truncated to the last 5000 lines.
# | rollout/            |          |
# |    ep_len_mean      | 3.8e+03  |
# |    ep_rew_mean      | 396      |
# |    exploration_rate | 0.439    |
# | time/               |          |
# |    episodes         | 2836     |
# |    fps              | 271      |
# |    time_elapsed     | 2089     |
# |    total_timesteps  | 566390   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0214   |
# |    n_updates        | 116597   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81e+03 |
# |    ep_rew_mean      | 399      |
# |    exploration_rate | 0.438    |
# | time/               |          |
# |    episodes         | 2840     |
# |    fps              | 271      |
# |    time_elapsed     | 2093     |
# |    total_timesteps  | 567313   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0198   |
# |    n_updates        | 116828   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82e+03 |
# |    ep_rew_mean      | 401      |
# |    exploration_rate | 0.437    |
# | time/               |          |
# |    episodes         | 2844     |
# |    fps              | 270      |
# |    time_elapsed     | 2100     |
# |    total_timesteps  | 569158   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0151   |
# |    n_updates        | 117289   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79e+03 |
# |    ep_rew_mean      | 395      |
# |    exploration_rate | 0.435    |
# | time/               |          |
# |    episodes         | 2848     |
# |    fps              | 270      |
# |    time_elapsed     | 2105     |
# |    total_timesteps  | 570409   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0073   |
# |    n_updates        | 117602   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79e+03 |
# |    ep_rew_mean      | 394      |
# |    exploration_rate | 0.434    |
# | time/               |          |
# |    episodes         | 2852     |
# |    fps              | 270      |
# |    time_elapsed     | 2109     |
# |    total_timesteps  | 571343   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00826  |
# |    n_updates        | 117835   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78e+03 |
# |    ep_rew_mean      | 393      |
# |    exploration_rate | 0.433    |
# | time/               |          |
# |    episodes         | 2856     |
# |    fps              | 270      |
# |    time_elapsed     | 2114     |
# |    total_timesteps  | 572555   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0255   |
# |    n_updates        | 118138   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81e+03 |
# |    ep_rew_mean      | 399      |
# |    exploration_rate | 0.431    |
# | time/               |          |
# |    episodes         | 2860     |
# |    fps              | 270      |
# |    time_elapsed     | 2120     |
# |    total_timesteps  | 574270   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0665   |
# |    n_updates        | 118567   |
# ----------------------------------
# Eval num_timesteps=575000, episode_reward=488.00 +/- 251.43
# Episode length: 4311.20 +/- 1111.68
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.31e+03 |
# |    mean_reward      | 488      |
# | rollout/            |          |
# |    exploration_rate | 0.431    |
# | time/               |          |
# |    total_timesteps  | 575000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0226   |
# |    n_updates        | 118749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81e+03 |
# |    ep_rew_mean      | 400      |
# |    exploration_rate | 0.43     |
# | time/               |          |
# |    episodes         | 2864     |
# |    fps              | 269      |
# |    time_elapsed     | 2138     |
# |    total_timesteps  | 575540   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00892  |
# |    n_updates        | 118884   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8e+03  |
# |    ep_rew_mean      | 399      |
# |    exploration_rate | 0.429    |
# | time/               |          |
# |    episodes         | 2868     |
# |    fps              | 268      |
# |    time_elapsed     | 2145     |
# |    total_timesteps  | 577025   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0837   |
# |    n_updates        | 119256   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78e+03 |
# |    ep_rew_mean      | 403      |
# |    exploration_rate | 0.427    |
# | time/               |          |
# |    episodes         | 2872     |
# |    fps              | 269      |
# |    time_elapsed     | 2152     |
# |    total_timesteps  | 579161   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.085    |
# |    n_updates        | 119790   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78e+03 |
# |    ep_rew_mean      | 409      |
# |    exploration_rate | 0.424    |
# | time/               |          |
# |    episodes         | 2876     |
# |    fps              | 268      |
# |    time_elapsed     | 2162     |
# |    total_timesteps  | 581504   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0116   |
# |    n_updates        | 120375   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78e+03 |
# |    ep_rew_mean      | 408      |
# |    exploration_rate | 0.423    |
# | time/               |          |
# |    episodes         | 2880     |
# |    fps              | 268      |
# |    time_elapsed     | 2167     |
# |    total_timesteps  | 582729   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0423   |
# |    n_updates        | 120682   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78e+03 |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.422    |
# | time/               |          |
# |    episodes         | 2884     |
# |    fps              | 268      |
# |    time_elapsed     | 2172     |
# |    total_timesteps  | 583950   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0409   |
# |    n_updates        | 120987   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78e+03 |
# |    ep_rew_mean      | 409      |
# |    exploration_rate | 0.42     |
# | time/               |          |
# |    episodes         | 2888     |
# |    fps              | 268      |
# |    time_elapsed     | 2178     |
# |    total_timesteps  | 585583   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0253   |
# |    n_updates        | 121395   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.76e+03 |
# |    ep_rew_mean      | 412      |
# |    exploration_rate | 0.419    |
# | time/               |          |
# |    episodes         | 2892     |
# |    fps              | 268      |
# |    time_elapsed     | 2183     |
# |    total_timesteps  | 586654   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0384   |
# |    n_updates        | 121663   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.77e+03 |
# |    ep_rew_mean      | 412      |
# |    exploration_rate | 0.418    |
# | time/               |          |
# |    episodes         | 2896     |
# |    fps              | 268      |
# |    time_elapsed     | 2191     |
# |    total_timesteps  | 588383   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0285   |
# |    n_updates        | 122095   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.76e+03 |
# |    ep_rew_mean      | 411      |
# |    exploration_rate | 0.416    |
# | time/               |          |
# |    episodes         | 2900     |
# |    fps              | 268      |
# |    time_elapsed     | 2195     |
# |    total_timesteps  | 589478   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0193   |
# |    n_updates        | 122369   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.73e+03 |
# |    ep_rew_mean      | 413      |
# |    exploration_rate | 0.416    |
# | time/               |          |
# |    episodes         | 2904     |
# |    fps              | 268      |
# |    time_elapsed     | 2198     |
# |    total_timesteps  | 590253   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0246   |
# |    n_updates        | 122563   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | 414      |
# |    exploration_rate | 0.415    |
# | time/               |          |
# |    episodes         | 2908     |
# |    fps              | 268      |
# |    time_elapsed     | 2203     |
# |    total_timesteps  | 591388   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0597   |
# |    n_updates        | 122846   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.74e+03 |
# |    ep_rew_mean      | 412      |
# |    exploration_rate | 0.413    |
# | time/               |          |
# |    episodes         | 2912     |
# |    fps              | 268      |
# |    time_elapsed     | 2208     |
# |    total_timesteps  | 592758   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0244   |
# |    n_updates        | 123189   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | 411      |
# |    exploration_rate | 0.412    |
# | time/               |          |
# |    episodes         | 2916     |
# |    fps              | 268      |
# |    time_elapsed     | 2213     |
# |    total_timesteps  | 594109   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0159   |
# |    n_updates        | 123527   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.76e+03 |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.41     |
# | time/               |          |
# |    episodes         | 2920     |
# |    fps              | 268      |
# |    time_elapsed     | 2221     |
# |    total_timesteps  | 596146   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0135   |
# |    n_updates        | 124036   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8e+03  |
# |    ep_rew_mean      | 414      |
# |    exploration_rate | 0.408    |
# | time/               |          |
# |    episodes         | 2924     |
# |    fps              | 268      |
# |    time_elapsed     | 2230     |
# |    total_timesteps  | 598446   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0168   |
# |    n_updates        | 124611   |
# ----------------------------------
# Eval num_timesteps=600000, episode_reward=433.00 +/- 83.22
# Episode length: 4152.80 +/- 297.51
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.15e+03 |
# |    mean_reward      | 433      |
# | rollout/            |          |
# |    exploration_rate | 0.406    |
# | time/               |          |
# |    total_timesteps  | 600000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0183   |
# |    n_updates        | 124999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82e+03 |
# |    ep_rew_mean      | 419      |
# |    exploration_rate | 0.406    |
# | time/               |          |
# |    episodes         | 2928     |
# |    fps              | 266      |
# |    time_elapsed     | 2247     |
# |    total_timesteps  | 600173   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0166   |
# |    n_updates        | 125043   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81e+03 |
# |    ep_rew_mean      | 416      |
# |    exploration_rate | 0.405    |
# | time/               |          |
# |    episodes         | 2932     |
# |    fps              | 266      |
# |    time_elapsed     | 2252     |
# |    total_timesteps  | 601268   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00857  |
# |    n_updates        | 125316   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8e+03  |
# |    ep_rew_mean      | 414      |
# |    exploration_rate | 0.404    |
# | time/               |          |
# |    episodes         | 2936     |
# |    fps              | 266      |
# |    time_elapsed     | 2257     |
# |    total_timesteps  | 602402   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 125600   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8e+03  |
# |    ep_rew_mean      | 409      |
# |    exploration_rate | 0.402    |
# | time/               |          |
# |    episodes         | 2940     |
# |    fps              | 266      |
# |    time_elapsed     | 2261     |
# |    total_timesteps  | 603610   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0362   |
# |    n_updates        | 125902   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78e+03 |
# |    ep_rew_mean      | 406      |
# |    exploration_rate | 0.401    |
# | time/               |          |
# |    episodes         | 2944     |
# |    fps              | 266      |
# |    time_elapsed     | 2268     |
# |    total_timesteps  | 605212   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0131   |
# |    n_updates        | 126302   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.77e+03 |
# |    ep_rew_mean      | 404      |
# |    exploration_rate | 0.4      |
# | time/               |          |
# |    episodes         | 2948     |
# |    fps              | 266      |
# |    time_elapsed     | 2272     |
# |    total_timesteps  | 606292   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0304   |
# |    n_updates        | 126572   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.77e+03 |
# |    ep_rew_mean      | 403      |
# |    exploration_rate | 0.399    |
# | time/               |          |
# |    episodes         | 2952     |
# |    fps              | 266      |
# |    time_elapsed     | 2276     |
# |    total_timesteps  | 607347   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00893  |
# |    n_updates        | 126836   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79e+03 |
# |    ep_rew_mean      | 405      |
# |    exploration_rate | 0.398    |
# | time/               |          |
# |    episodes         | 2956     |
# |    fps              | 266      |
# |    time_elapsed     | 2282     |
# |    total_timesteps  | 608448   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0278   |
# |    n_updates        | 127111   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.76e+03 |
# |    ep_rew_mean      | 403      |
# |    exploration_rate | 0.397    |
# | time/               |          |
# |    episodes         | 2960     |
# |    fps              | 266      |
# |    time_elapsed     | 2286     |
# |    total_timesteps  | 609545   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 127386   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | 402      |
# |    exploration_rate | 0.395    |
# | time/               |          |
# |    episodes         | 2964     |
# |    fps              | 266      |
# |    time_elapsed     | 2290     |
# |    total_timesteps  | 610648   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0331   |
# |    n_updates        | 127661   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.72e+03 |
# |    ep_rew_mean      | 398      |
# |    exploration_rate | 0.395    |
# | time/               |          |
# |    episodes         | 2968     |
# |    fps              | 266      |
# |    time_elapsed     | 2295     |
# |    total_timesteps  | 611525   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0453   |
# |    n_updates        | 127881   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.72e+03 |
# |    ep_rew_mean      | 399      |
# |    exploration_rate | 0.394    |
# | time/               |          |
# |    episodes         | 2972     |
# |    fps              | 266      |
# |    time_elapsed     | 2298     |
# |    total_timesteps  | 612500   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0259   |
# |    n_updates        | 128124   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.72e+03 |
# |    ep_rew_mean      | 400      |
# |    exploration_rate | 0.393    |
# | time/               |          |
# |    episodes         | 2976     |
# |    fps              | 266      |
# |    time_elapsed     | 2302     |
# |    total_timesteps  | 613435   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0376   |
# |    n_updates        | 128358   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71e+03 |
# |    ep_rew_mean      | 399      |
# |    exploration_rate | 0.392    |
# | time/               |          |
# |    episodes         | 2980     |
# |    fps              | 266      |
# |    time_elapsed     | 2306     |
# |    total_timesteps  | 614494   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0367   |
# |    n_updates        | 128623   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.69e+03 |
# |    ep_rew_mean      | 396      |
# |    exploration_rate | 0.39     |
# | time/               |          |
# |    episodes         | 2984     |
# |    fps              | 266      |
# |    time_elapsed     | 2312     |
# |    total_timesteps  | 616002   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00744  |
# |    n_updates        | 129000   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.68e+03 |
# |    ep_rew_mean      | 398      |
# |    exploration_rate | 0.389    |
# | time/               |          |
# |    episodes         | 2988     |
# |    fps              | 266      |
# |    time_elapsed     | 2316     |
# |    total_timesteps  | 617177   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0312   |
# |    n_updates        | 129294   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.67e+03 |
# |    ep_rew_mean      | 398      |
# |    exploration_rate | 0.387    |
# | time/               |          |
# |    episodes         | 2992     |
# |    fps              | 266      |
# |    time_elapsed     | 2323     |
# |    total_timesteps  | 618699   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.014    |
# |    n_updates        | 129674   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.7e+03  |
# |    ep_rew_mean      | 403      |
# |    exploration_rate | 0.387    |
# | time/               |          |
# |    episodes         | 2996     |
# |    fps              | 266      |
# |    time_elapsed     | 2327     |
# |    total_timesteps  | 619683   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0206   |
# |    n_updates        | 129920   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.69e+03 |
# |    ep_rew_mean      | 400      |
# |    exploration_rate | 0.385    |
# | time/               |          |
# |    episodes         | 3000     |
# |    fps              | 266      |
# |    time_elapsed     | 2332     |
# |    total_timesteps  | 621213   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0573   |
# |    n_updates        | 130303   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.69e+03 |
# |    ep_rew_mean      | 404      |
# |    exploration_rate | 0.384    |
# | time/               |          |
# |    episodes         | 3004     |
# |    fps              | 266      |
# |    time_elapsed     | 2336     |
# |    total_timesteps  | 622115   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0122   |
# |    n_updates        | 130528   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.7e+03  |
# |    ep_rew_mean      | 407      |
# |    exploration_rate | 0.382    |
# | time/               |          |
# |    episodes         | 3008     |
# |    fps              | 266      |
# |    time_elapsed     | 2344     |
# |    total_timesteps  | 624139   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0183   |
# |    n_updates        | 131034   |
# ----------------------------------
# Eval num_timesteps=625000, episode_reward=332.00 +/- 110.39
# Episode length: 3411.00 +/- 1002.80
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.41e+03 |
# |    mean_reward      | 332      |
# | rollout/            |          |
# |    exploration_rate | 0.381    |
# | time/               |          |
# |    total_timesteps  | 625000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0187   |
# |    n_updates        | 131249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.7e+03  |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.38     |
# | time/               |          |
# |    episodes         | 3012     |
# |    fps              | 265      |
# |    time_elapsed     | 2360     |
# |    total_timesteps  | 625979   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0251   |
# |    n_updates        | 131494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.7e+03  |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.379    |
# | time/               |          |
# |    episodes         | 3016     |
# |    fps              | 265      |
# |    time_elapsed     | 2364     |
# |    total_timesteps  | 626946   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0251   |
# |    n_updates        | 131736   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71e+03 |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.377    |
# | time/               |          |
# |    episodes         | 3020     |
# |    fps              | 265      |
# |    time_elapsed     | 2373     |
# |    total_timesteps  | 629281   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0236   |
# |    n_updates        | 132320   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.73e+03 |
# |    ep_rew_mean      | 412      |
# |    exploration_rate | 0.375    |
# | time/               |          |
# |    episodes         | 3024     |
# |    fps              | 265      |
# |    time_elapsed     | 2379     |
# |    total_timesteps  | 630837   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0305   |
# |    n_updates        | 132709   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.373    |
# | time/               |          |
# |    episodes         | 3028     |
# |    fps              | 265      |
# |    time_elapsed     | 2387     |
# |    total_timesteps  | 633016   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0398   |
# |    n_updates        | 133253   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.372    |
# | time/               |          |
# |    episodes         | 3032     |
# |    fps              | 265      |
# |    time_elapsed     | 2393     |
# |    total_timesteps  | 634399   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0152   |
# |    n_updates        | 133599   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | 411      |
# |    exploration_rate | 0.37     |
# | time/               |          |
# |    episodes         | 3036     |
# |    fps              | 265      |
# |    time_elapsed     | 2399     |
# |    total_timesteps  | 636059   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0147   |
# |    n_updates        | 134014   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78e+03 |
# |    ep_rew_mean      | 415      |
# |    exploration_rate | 0.368    |
# | time/               |          |
# |    episodes         | 3040     |
# |    fps              | 265      |
# |    time_elapsed     | 2407     |
# |    total_timesteps  | 638002   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0157   |
# |    n_updates        | 134500   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8e+03  |
# |    ep_rew_mean      | 424      |
# |    exploration_rate | 0.366    |
# | time/               |          |
# |    episodes         | 3044     |
# |    fps              | 264      |
# |    time_elapsed     | 2416     |
# |    total_timesteps  | 640336   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0479   |
# |    n_updates        | 135083   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8e+03  |
# |    ep_rew_mean      | 427      |
# |    exploration_rate | 0.364    |
# | time/               |          |
# |    episodes         | 3048     |
# |    fps              | 264      |
# |    time_elapsed     | 2424     |
# |    total_timesteps  | 642438   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 135609   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82e+03 |
# |    ep_rew_mean      | 431      |
# |    exploration_rate | 0.362    |
# | time/               |          |
# |    episodes         | 3052     |
# |    fps              | 264      |
# |    time_elapsed     | 2432     |
# |    total_timesteps  | 644161   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0212   |
# |    n_updates        | 136040   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.85e+03 |
# |    ep_rew_mean      | 435      |
# |    exploration_rate | 0.361    |
# | time/               |          |
# |    episodes         | 3056     |
# |    fps              | 264      |
# |    time_elapsed     | 2438     |
# |    total_timesteps  | 645665   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0159   |
# |    n_updates        | 136416   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.85e+03 |
# |    ep_rew_mean      | 437      |
# |    exploration_rate | 0.359    |
# | time/               |          |
# |    episodes         | 3060     |
# |    fps              | 264      |
# |    time_elapsed     | 2446     |
# |    total_timesteps  | 647748   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0204   |
# |    n_updates        | 136936   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.86e+03 |
# |    ep_rew_mean      | 436      |
# |    exploration_rate | 0.357    |
# | time/               |          |
# |    episodes         | 3064     |
# |    fps              | 264      |
# |    time_elapsed     | 2452     |
# |    total_timesteps  | 649343   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 137335   |
# ----------------------------------
# Eval num_timesteps=650000, episode_reward=427.00 +/- 150.88
# Episode length: 3560.80 +/- 918.71
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.56e+03 |
# |    mean_reward      | 427      |
# | rollout/            |          |
# |    exploration_rate | 0.357    |
# | time/               |          |
# |    total_timesteps  | 650000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.134    |
# |    n_updates        | 137499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.87e+03 |
# |    ep_rew_mean      | 440      |
# |    exploration_rate | 0.356    |
# | time/               |          |
# |    episodes         | 3068     |
# |    fps              | 263      |
# |    time_elapsed     | 2467     |
# |    total_timesteps  | 650574   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0196   |
# |    n_updates        | 137643   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88e+03 |
# |    ep_rew_mean      | 440      |
# |    exploration_rate | 0.355    |
# | time/               |          |
# |    episodes         | 3072     |
# |    fps              | 263      |
# |    time_elapsed     | 2472     |
# |    total_timesteps  | 651706   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.017    |
# |    n_updates        | 137926   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.85e+03 |
# |    ep_rew_mean      | 441      |
# |    exploration_rate | 0.352    |
# | time/               |          |
# |    episodes         | 3076     |
# |    fps              | 263      |
# |    time_elapsed     | 2481     |
# |    total_timesteps  | 654175   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0266   |
# |    n_updates        | 138543   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84e+03 |
# |    ep_rew_mean      | 444      |
# |    exploration_rate | 0.351    |
# | time/               |          |
# |    episodes         | 3080     |
# |    fps              | 263      |
# |    time_elapsed     | 2486     |
# |    total_timesteps  | 655250   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0391   |
# |    n_updates        | 138812   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84e+03 |
# |    ep_rew_mean      | 446      |
# |    exploration_rate | 0.35     |
# | time/               |          |
# |    episodes         | 3084     |
# |    fps              | 263      |
# |    time_elapsed     | 2492     |
# |    total_timesteps  | 656915   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0896   |
# |    n_updates        | 139228   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84e+03 |
# |    ep_rew_mean      | 448      |
# |    exploration_rate | 0.348    |
# | time/               |          |
# |    episodes         | 3088     |
# |    fps              | 263      |
# |    time_elapsed     | 2501     |
# |    total_timesteps  | 658599   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00611  |
# |    n_updates        | 139649   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.83e+03 |
# |    ep_rew_mean      | 447      |
# |    exploration_rate | 0.347    |
# | time/               |          |
# |    episodes         | 3092     |
# |    fps              | 263      |
# |    time_elapsed     | 2504     |
# |    total_timesteps  | 659585   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0271   |
# |    n_updates        | 139896   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.83e+03 |
# |    ep_rew_mean      | 447      |
# |    exploration_rate | 0.346    |
# | time/               |          |
# |    episodes         | 3096     |
# |    fps              | 263      |
# |    time_elapsed     | 2510     |
# |    total_timesteps  | 661084   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0146   |
# |    n_updates        | 140270   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84e+03 |
# |    ep_rew_mean      | 448      |
# |    exploration_rate | 0.344    |
# | time/               |          |
# |    episodes         | 3100     |
# |    fps              | 263      |
# |    time_elapsed     | 2517     |
# |    total_timesteps  | 662759   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.135    |
# |    n_updates        | 140689   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84e+03 |
# |    ep_rew_mean      | 446      |
# |    exploration_rate | 0.343    |
# | time/               |          |
# |    episodes         | 3104     |
# |    fps              | 263      |
# |    time_elapsed     | 2522     |
# |    total_timesteps  | 664106   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0364   |
# |    n_updates        | 141026   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.85e+03 |
# |    ep_rew_mean      | 449      |
# |    exploration_rate | 0.341    |
# | time/               |          |
# |    episodes         | 3108     |
# |    fps              | 263      |
# |    time_elapsed     | 2530     |
# |    total_timesteps  | 665987   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0696   |
# |    n_updates        | 141496   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.87e+03 |
# |    ep_rew_mean      | 449      |
# |    exploration_rate | 0.339    |
# | time/               |          |
# |    episodes         | 3112     |
# |    fps              | 263      |
# |    time_elapsed     | 2534     |
# |    total_timesteps  | 667181   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00795  |
# |    n_updates        | 141795   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84e+03 |
# |    ep_rew_mean      | 447      |
# |    exploration_rate | 0.338    |
# | time/               |          |
# |    episodes         | 3116     |
# |    fps              | 263      |
# |    time_elapsed     | 2539     |
# |    total_timesteps  | 668324   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0217   |
# |    n_updates        | 142080   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.86e+03 |
# |    ep_rew_mean      | 449      |
# |    exploration_rate | 0.336    |
# | time/               |          |
# |    episodes         | 3120     |
# |    fps              | 263      |
# |    time_elapsed     | 2547     |
# |    total_timesteps  | 670352   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0332   |
# |    n_updates        | 142587   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.87e+03 |
# |    ep_rew_mean      | 458      |
# |    exploration_rate | 0.334    |
# | time/               |          |
# |    episodes         | 3124     |
# |    fps              | 263      |
# |    time_elapsed     | 2558     |
# |    total_timesteps  | 673126   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0404   |
# |    n_updates        | 143281   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.86e+03 |
# |    ep_rew_mean      | 452      |
# |    exploration_rate | 0.332    |
# | time/               |          |
# |    episodes         | 3128     |
# |    fps              | 263      |
# |    time_elapsed     | 2562     |
# |    total_timesteps  | 674260   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 143564   |
# ----------------------------------
# Eval num_timesteps=675000, episode_reward=510.00 +/- 279.73
# Episode length: 3462.20 +/- 855.10
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.46e+03 |
# |    mean_reward      | 510      |
# | rollout/            |          |
# |    exploration_rate | 0.332    |
# | time/               |          |
# |    total_timesteps  | 675000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.03     |
# |    n_updates        | 143749   |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.85e+03 |
# |    ep_rew_mean      | 450      |
# |    exploration_rate | 0.331    |
# | time/               |          |
# |    episodes         | 3132     |
# |    fps              | 261      |
# |    time_elapsed     | 2580     |
# |    total_timesteps  | 675879   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0127   |
# |    n_updates        | 143969   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.83e+03 |
# |    ep_rew_mean      | 450      |
# |    exploration_rate | 0.329    |
# | time/               |          |
# |    episodes         | 3136     |
# |    fps              | 261      |
# |    time_elapsed     | 2586     |
# |    total_timesteps  | 677351   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0218   |
# |    n_updates        | 144337   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82e+03 |
# |    ep_rew_mean      | 449      |
# |    exploration_rate | 0.328    |
# | time/               |          |
# |    episodes         | 3140     |
# |    fps              | 261      |
# |    time_elapsed     | 2589     |
# |    total_timesteps  | 678320   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.049    |
# |    n_updates        | 144579   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82e+03 |
# |    ep_rew_mean      | 448      |
# |    exploration_rate | 0.327    |
# | time/               |          |
# |    episodes         | 3144     |
# |    fps              | 261      |
# |    time_elapsed     | 2595     |
# |    total_timesteps  | 679633   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0255   |
# |    n_updates        | 144908   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78e+03 |
# |    ep_rew_mean      | 443      |
# |    exploration_rate | 0.326    |
# | time/               |          |
# |    episodes         | 3148     |
# |    fps              | 261      |
# |    time_elapsed     | 2601     |
# |    total_timesteps  | 681226   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0244   |
# |    n_updates        | 145306   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.77e+03 |
# |    ep_rew_mean      | 441      |
# |    exploration_rate | 0.325    |
# | time/               |          |
# |    episodes         | 3152     |
# |    fps              | 261      |
# |    time_elapsed     | 2604     |
# |    total_timesteps  | 682017   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0293   |
# |    n_updates        | 145504   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.76e+03 |
# |    ep_rew_mean      | 441      |
# |    exploration_rate | 0.323    |
# | time/               |          |
# |    episodes         | 3156     |
# |    fps              | 261      |
# |    time_elapsed     | 2610     |
# |    total_timesteps  | 683366   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 145841   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | 441      |
# |    exploration_rate | 0.323    |
# | time/               |          |
# |    episodes         | 3160     |
# |    fps              | 261      |
# |    time_elapsed     | 2613     |
# |    total_timesteps  | 684085   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0192   |
# |    n_updates        | 146021   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.74e+03 |
# |    ep_rew_mean      | 439      |
# |    exploration_rate | 0.321    |
# | time/               |          |
# |    episodes         | 3164     |
# |    fps              | 261      |
# |    time_elapsed     | 2620     |
# |    total_timesteps  | 685856   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0489   |
# |    n_updates        | 146463   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.72e+03 |
# |    ep_rew_mean      | 438      |
# |    exploration_rate | 0.32     |
# | time/               |          |
# |    episodes         | 3168     |
# |    fps              | 261      |
# |    time_elapsed     | 2625     |
# |    total_timesteps  | 687175   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0205   |
# |    n_updates        | 146793   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71e+03 |
# |    ep_rew_mean      | 436      |
# |    exploration_rate | 0.319    |
# | time/               |          |
# |    episodes         | 3172     |
# |    fps              | 261      |
# |    time_elapsed     | 2630     |
# |    total_timesteps  | 688314   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00913  |
# |    n_updates        | 147078   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63e+03 |
# |    ep_rew_mean      | 425      |
# |    exploration_rate | 0.318    |
# | time/               |          |
# |    episodes         | 3176     |
# |    fps              | 261      |
# |    time_elapsed     | 2633     |
# |    total_timesteps  | 689215   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 147303   |
# ----------------------------------
# ----------------------------------
# ...
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0409   |
# |    n_updates        | 218487   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=400.00 +/- 129.65
# Episode length: 3817.00 +/- 659.51
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.82e+03 |
# |    mean_reward      | 400      |
# | rollout/            |          |
# |    exploration_rate | 0.0348   |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.132    |
# |    n_updates        | 218749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | 568      |
# |    exploration_rate | 0.0342   |
# | time/               |          |
# |    episodes         | 3984     |
# |    fps              | 247      |
# |    time_elapsed     | 3946     |
# |    total_timesteps  | 975511   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0228   |
# |    n_updates        | 218877   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.93e+03 |
# |    ep_rew_mean      | 566      |
# |    exploration_rate | 0.0328   |
# | time/               |          |
# |    episodes         | 3988     |
# |    fps              | 247      |
# |    time_elapsed     | 3953     |
# |    total_timesteps  | 977001   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0232   |
# |    n_updates        | 219250   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.95e+03 |
# |    ep_rew_mean      | 567      |
# |    exploration_rate | 0.0311   |
# | time/               |          |
# |    episodes         | 3992     |
# |    fps              | 247      |
# |    time_elapsed     | 3959     |
# |    total_timesteps  | 978706   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0216   |
# |    n_updates        | 219676   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.99e+03 |
# |    ep_rew_mean      | 570      |
# |    exploration_rate | 0.0296   |
# | time/               |          |
# |    episodes         | 3996     |
# |    fps              | 247      |
# |    time_elapsed     | 3966     |
# |    total_timesteps  | 980157   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.053    |
# |    n_updates        | 220039   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.98e+03 |
# |    ep_rew_mean      | 571      |
# |    exploration_rate | 0.0285   |
# | time/               |          |
# |    episodes         | 4000     |
# |    fps              | 247      |
# |    time_elapsed     | 3971     |
# |    total_timesteps  | 981338   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0157   |
# |    n_updates        | 220334   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.98e+03 |
# |    ep_rew_mean      | 572      |
# |    exploration_rate | 0.0274   |
# | time/               |          |
# |    episodes         | 4004     |
# |    fps              | 247      |
# |    time_elapsed     | 3975     |
# |    total_timesteps  | 982403   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0116   |
# |    n_updates        | 220600   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.98e+03 |
# |    ep_rew_mean      | 572      |
# |    exploration_rate | 0.0255   |
# | time/               |          |
# |    episodes         | 4008     |
# |    fps              | 247      |
# |    time_elapsed     | 3983     |
# |    total_timesteps  | 984327   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0387   |
# |    n_updates        | 221081   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02e+03 |
# |    ep_rew_mean      | 577      |
# |    exploration_rate | 0.0236   |
# | time/               |          |
# |    episodes         | 4012     |
# |    fps              | 247      |
# |    time_elapsed     | 3992     |
# |    total_timesteps  | 986291   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0397   |
# |    n_updates        | 221572   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02e+03 |
# |    ep_rew_mean      | 580      |
# |    exploration_rate | 0.0217   |
# | time/               |          |
# |    episodes         | 4016     |
# |    fps              | 247      |
# |    time_elapsed     | 4000     |
# |    total_timesteps  | 988215   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0253   |
# |    n_updates        | 222053   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 577      |
# |    exploration_rate | 0.0203   |
# | time/               |          |
# |    episodes         | 4020     |
# |    fps              | 246      |
# |    time_elapsed     | 4007     |
# |    total_timesteps  | 989583   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00637  |
# |    n_updates        | 222395   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 581      |
# |    exploration_rate | 0.0182   |
# | time/               |          |
# |    episodes         | 4024     |
# |    fps              | 246      |
# |    time_elapsed     | 4015     |
# |    total_timesteps  | 991679   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 222919   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04e+03 |
# |    ep_rew_mean      | 581      |
# |    exploration_rate | 0.0155   |
# | time/               |          |
# |    episodes         | 4028     |
# |    fps              | 246      |
# |    time_elapsed     | 4027     |
# |    total_timesteps  | 994470   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0302   |
# |    n_updates        | 223617   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.07e+03 |
# |    ep_rew_mean      | 581      |
# |    exploration_rate | 0.014    |
# | time/               |          |
# |    episodes         | 4032     |
# |    fps              | 246      |
# |    time_elapsed     | 4035     |
# |    total_timesteps  | 995962   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0268   |
# |    n_updates        | 223990   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11e+03 |
# |    ep_rew_mean      | 589      |
# |    exploration_rate | 0.0124   |
# | time/               |          |
# |    episodes         | 4036     |
# |    fps              | 246      |
# |    time_elapsed     | 4041     |
# |    total_timesteps  | 997535   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 224383   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.12e+03 |
# |    ep_rew_mean      | 591      |
# |    exploration_rate | 0.0103   |
# | time/               |          |
# |    episodes         | 4040     |
# |    fps              | 246      |
# |    time_elapsed     | 4051     |
# |    total_timesteps  | 999698   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0159   |
# |    n_updates        | 224924   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=559.00 +/- 221.32
# Episode length: 5135.40 +/- 881.25
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 5.14e+03 |
# |    mean_reward      | 559      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0504   |
# |    n_updates        | 224999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.17e+03 |
# |    ep_rew_mean      | 592      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4044     |
# |    fps              | 245      |
# |    time_elapsed     | 4079     |
# |    total_timesteps  | 1002750  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0503   |
# |    n_updates        | 225687   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.17e+03 |
# |    ep_rew_mean      | 592      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4048     |
# |    fps              | 245      |
# |    time_elapsed     | 4083     |
# |    total_timesteps  | 1003668  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0381   |
# |    n_updates        | 225916   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.19e+03 |
# |    ep_rew_mean      | 596      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4052     |
# |    fps              | 245      |
# |    time_elapsed     | 4089     |
# |    total_timesteps  | 1004936  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00914  |
# |    n_updates        | 226233   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.19e+03 |
# |    ep_rew_mean      | 595      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4056     |
# |    fps              | 245      |
# |    time_elapsed     | 4099     |
# |    total_timesteps  | 1007605  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0357   |
# |    n_updates        | 226901   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.24e+03 |
# |    ep_rew_mean      | 605      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4060     |
# |    fps              | 245      |
# |    time_elapsed     | 4106     |
# |    total_timesteps  | 1009113  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0485   |
# |    n_updates        | 227278   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.23e+03 |
# |    ep_rew_mean      | 607      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4064     |
# |    fps              | 245      |
# |    time_elapsed     | 4112     |
# |    total_timesteps  | 1010570  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0279   |
# |    n_updates        | 227642   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.21e+03 |
# |    ep_rew_mean      | 600      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4068     |
# |    fps              | 245      |
# |    time_elapsed     | 4119     |
# |    total_timesteps  | 1012120  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0297   |
# |    n_updates        | 228029   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.2e+03  |
# |    ep_rew_mean      | 605      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4072     |
# |    fps              | 245      |
# |    time_elapsed     | 4128     |
# |    total_timesteps  | 1014246  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0167   |
# |    n_updates        | 228561   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.21e+03 |
# |    ep_rew_mean      | 608      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4076     |
# |    fps              | 245      |
# |    time_elapsed     | 4132     |
# |    total_timesteps  | 1015132  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0322   |
# |    n_updates        | 228782   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.21e+03 |
# |    ep_rew_mean      | 610      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4080     |
# |    fps              | 245      |
# |    time_elapsed     | 4144     |
# |    total_timesteps  | 1017829  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0276   |
# |    n_updates        | 229457   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.23e+03 |
# |    ep_rew_mean      | 610      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4084     |
# |    fps              | 245      |
# |    time_elapsed     | 4153     |
# |    total_timesteps  | 1020045  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00679  |
# |    n_updates        | 230011   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.24e+03 |
# |    ep_rew_mean      | 613      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4088     |
# |    fps              | 245      |
# |    time_elapsed     | 4159     |
# |    total_timesteps  | 1021162  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.032    |
# |    n_updates        | 230290   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.25e+03 |
# |    ep_rew_mean      | 606      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4092     |
# |    fps              | 245      |
# |    time_elapsed     | 4164     |
# |    total_timesteps  | 1022554  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0298   |
# |    n_updates        | 230638   |
# ----------------------------------
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_1
# ^C

# %% [markdown]
# ## Let's evaluate our agent 👀
# - RL-Baselines3-Zoo provides `enjoy.py`, a python script to evaluate our agent. In most RL libraries, we call the evaluation script `enjoy.py`.
# - Let's evaluate it for 5000 timesteps 🔥

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# 2023-08-21 23:27:39.552624: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-21 23:27:41.006855: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: 265.00
# Atari Episode Length 3522
# Atari Episode Score: 275.00
# Atari Episode Length 3961
# Atari Episode Score: 515.00
# Atari Episode Length 4091
# Atari Episode Score: 200.00
# Atari Episode Length 3921
# Atari Episode Score: 270.00
# Atari Episode Length 3916

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/

# %% [markdown]
# ## Publish our trained model on the Hub 🚀
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/space-invaders-model.gif" alt="Space Invaders model">

# %% [markdown]
# By using `rl_zoo3.push_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉  https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">

# %% [markdown]
# - Copy the token
# - Run the cell below and past the token

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥

# %% [markdown]
# Let's run push_to_hub.py file to upload our trained agent to the Hub.
#
# `--repo-name `: The name of the repo
#
# `-orga`: Your Hugging Face username
#
# `-f`: Where the trained model folder is (in our case `logs`)
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/select-id.png" alt="Select Id">

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn_atari -orga logs -f logs/
# Out:
# 2023-08-21 23:29:58.348460: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-21 23:29:59.731443: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to logs/dqn_atari, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py", line 261, in hf_raise_for_status
#     response.raise_for_status()
#   File "/usr/local/lib/python3.10/dist-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/api/repos/create
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/huggingface_hub/hf_api.py", line 2308, in create_repo
#     hf_raise_for_status(r)
#   File "/usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py", line 303, in hf_raise_for_status
#     raise HfHubHTTPError(str(e), response=response) from e
# huggingface_hub.utils._errors.HfHubHTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/api/repos/create (Request ID: Root=1-64e3f37d-299845ae3df25bf51718d075;1b99c7c3-186f-45c6-a690-4af5ea32bef6)
#
# You don't have the rights to create a model under this namespace
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py", line 261, in hf_raise_for_status
#     response.raise_for_status()
#   File "/usr/local/lib/python3.10/dist-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/api/models/logs/dqn_atari
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.10/dist-packages/rl_zoo3/push_to_hub.py", line 416, in <module>
#     package_to_hub(
#   File "/usr/local/lib/python3.10/dist-packages/rl_zoo3/push_to_hub.py", line 192, in package_to_hub
#     repo_url = api.create_repo(
#   File "/usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py", line 118, in _inner_fn
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/huggingface_hub/hf_api.py", line 2316, in create_repo
#     self.repo_info(repo_id=repo_id, repo_type=repo_type, token=token)
#   File "/usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py", line 118, in _inner_fn
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/huggingface_hub/hf_api.py", line 1868, in repo_info
#     return method(
#   File "/usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py", line 118, in _inner_fn
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/huggingface_hub/hf_api.py", line 1678, in model_info
#     hf_raise_for_status(r)
#   File "/usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py", line 293, in hf_raise_for_status
#     raise RepositoryNotFoundError(message, response) from e
# huggingface_hub.utils._errors.RepositoryNotFoundError: 404 Client Error. (Request ID: Root=1-64e3f37e-1d68f1a026a6af4f0268dc87;cbb4b5b4-97f9-49eb-a4ef-4c476d0c8d4d)
#
# Repository Not Found for url: https://huggingface.co/api/models/logs/dqn_atari.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated.

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga ThomasSimonini  -f logs/

# %% [markdown]
# ###.

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Q-Learning agent using RL-Baselines-3 Zoo. The script above should have displayed a link to a model repository such as https://huggingface.co/ThomasSimonini/dqn-SpaceInvadersNoFrameskip-v4. When you go to this link, you can:
#
# - See a **video preview of your agent** at the right.
# - Click "Files and versions" to see all the files in the repository.
# - Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# - A model card (`README.md` file) which gives a description of the model and the hyperparameters you used.
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# **Compare the results of your agents with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆

# %% [markdown]
# ## Load a powerful trained model 🔥
# - The Stable-Baselines3 team uploaded **more than 150 trained Deep Reinforcement Learning agents on the Hub**.
#
# You can find them here: 👉 https://huggingface.co/sb3
#
# Some examples:
# - Asteroids: https://huggingface.co/sb3/dqn-AsteroidsNoFrameskip-v4
# - Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# - Breakout: https://huggingface.co/sb3/dqn-BreakoutNoFrameskip-v4
# - Road Runner: https://huggingface.co/sb3/dqn-RoadRunnerNoFrameskip-v4
#
# Let's load an agent playing Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# 1. We download the model using `rl_zoo3.load_from_hub`, and place it in a new folder that we can call `rl_trained`

# %%
# Download model and save it into the logs/ folder
# !python -m rl_zoo3.load_from_hub --algo dqn --env BeamRiderNoFrameskip-v4 -orga sb3 -f rl_trained/
# Out:
# 2023-08-21 23:30:34.491146: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-21 23:30:35.408749: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Downloading from https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# Downloading (…)erNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:00<00:00, 324MB/s]
# Downloading (…)olve/main/config.yml: 100% 548/548 [00:00<00:00, 3.18MB/s]
# No normalization file
# Downloading (…)esolve/main/args.yml: 100% 887/887 [00:00<00:00, 4.83MB/s]
# Downloading (…)/main/env_kwargs.yml: 100% 3.00/3.00 [00:00<00:00, 15.3kB/s]
# Downloading train_eval_metrics.zip: 100% 244k/244k [00:00<00:00, 302MB/s]
# Saving to rl_trained/dqn/BeamRiderNoFrameskip-v4_1

# %% [markdown]
# 2. Let's evaluate if for 5000 timesteps

# %%
# !python -m rl_zoo3.enjoy --algo dqn --env BeamRiderNoFrameskip-v4 -n 5000  -f rl_trained/ --no-render
# Out:
# 2023-08-21 23:30:49.330512: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-21 23:30:50.241771: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=1
# Loading rl_trained/dqn/BeamRiderNoFrameskip-v4_1/BeamRiderNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/save_util.py:166: UserWarning: Could not deserialize object exploration_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: 'bytes' object cannot be interpreted as an integer
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:95: UserWarning: You loaded a model that was trained using OpenAI Gym. We strongly recommend transitioning to Gymnasium by saving that model again.
#   warnings.warn(
# Atari Episode Score: 3028.00
# Atari Episode Length 14816

# %% [markdown]
# Why not trying to train your own **Deep Q-Learning Agent playing BeamRiderNoFrameskip-v4? 🏆.**
#
# If you want to try, check https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4#hyperparameters **in the model card, you have the hyperparameters of the trained agent.**

# %% [markdown]
# But finding hyperparameters can be a daunting task. Fortunately, we'll see in the next Unit, how we can **use Optuna for optimizing the Hyperparameters 🔥.**

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here's a list of environments you can try to train your agent with:
# - BeamRiderNoFrameskip-v4
# - BreakoutNoFrameskip-v4
# - EnduroNoFrameskip-v4
# - PongNoFrameskip-v4
#
# Also, **if you want to learn to implement Deep Q-Learning by yourself**, you definitely should look at CleanRL implementation: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/dqn_atari.py
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/atari-envs.gif" alt="Environments"/>

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter!
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and having a solid foundations.
#
# In the next unit, **we’re going to learn about [Optuna](https://optuna.org/)**. One of the most critical task in Deep Reinforcement Learning is to find a good set of training hyperparameters. And Optuna is a library that helps you to automate the search.

# %% [markdown]
# ### This is a course built with you 👷🏿‍♀️
#
# Finally, we want to improve and update the course iteratively with your feedback. If you have some, please fill this form 👉 https://forms.gle/3HgA7bEHwAmmLfwh9
#
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# See you on Bonus unit 2! 🔥

# %% [markdown]
# ### Keep Learning, Stay Awesome 🤗
